# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
model = LinearRegression()
model.fit(x_train.reshape(-1,1), y_train.reshape(-1,1))

# print the best fit slope and intercept
print("Best fit slope:", model.coef_)
print("Best fit intercept:", model.intercept_)

plt.scatter(x,y)
plt.plot(x_train, x_train*(model.coef_[0]) + model.intercept_[0], color = 'red')
# Out:
# Best fit slope: [[3.35638915]]
# Best fit intercept: [2.57550781]

# %%
x = np.random.normal(5,1,1000)
y = x*3.4 + 2.65 + np.random.randint(-8,8,1000)

# %%
x_train = x[0:800].reshape(800)
x_test = x[800:]
y_train = y[0:800]
y_test = y[800:]

# %% [raw]
# In conclusion the regression offered by the library sklearn is a far better estimation than the model developed by us and basic linear regression
